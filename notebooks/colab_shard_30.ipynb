# %% [markdown]
# # SCF Phase 2 shard 30
#
# Sweeps: power. Jobs: 17. Projected: 4.9 h
# (safety-factor 1.8x applied). Grids hash: `68970a975545`.
# Code source: github.com/hugogobato/scf-confounding-frontier @ tag `phase2-freeze` (pinned for
# reproducibility).
# Pre-registration: `docs/phase2_preregistration.md` (thresholds frozen before
# any data generation; deviation register D1-D7 included there).
#
# Resume-safe: completed cells are skipped on rerun (checkpoint parquet per
# cell). If the notebook approaches the Colab wall limit it finishes the
# current cell and stops cleanly; rerun to continue.

# %%
import os
for _v in ("OMP_NUM_THREADS", "OPENBLAS_NUM_THREADS", "MKL_NUM_THREADS",
           "NUMEXPR_NUM_THREADS", "VECLIB_MAXIMUM_THREADS"):
    os.environ[_v] = "1"
# !pip install -q "numpy>=2.0" "scipy>=1.14" "pandas>=2.2" "pyarrow>=16" scikit-learn

# %%
# !git clone --depth 1 --branch phase2-freeze \
    https://github.com/hugogobato/scf-confounding-frontier.git scf_repo
import sys, hashlib, json
sys.path.insert(0, "scf_repo/code")
# verify the pinned code matches the manifest recorded at generation time
EXPECTED = json.loads("{\"de_formulas.py\": \"5dffb441b638\", \"simulator.py\": \"ef31ca2a201b\", \"estimators.py\": \"7e27f25b2330\", \"detection.py\": \"06586fe60b9f\", \"runners.py\": \"df67486b60f5\"}")
for fname, short in EXPECTED.items():
    h = hashlib.sha256(open(f"scf_repo/code/{fname}", "rb").read()).hexdigest()[:12]
    assert h == short, f"code mismatch: {fname} ({h} != {short})"
print("code verified against generation-time hashes")

# %%
import json, time, traceback
from multiprocessing import Pool
from runners import run_cell

JOBS = json.loads("[{\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"sub\", \"label\": \"main\", \"g\": 0.4, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"605f6a5d79cc\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/605f6a5d79cc.parquet\", \"means_path\": \"data/sim/power/means/605f6a5d79cc.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"sub\", \"label\": \"main\", \"g\": 0.8, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"cbf10298ba9b\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/cbf10298ba9b.parquet\", \"means_path\": \"data/sim/power/means/cbf10298ba9b.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"sub\", \"label\": \"main\", \"g\": 1.6, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"055fea2d4bc0\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/055fea2d4bc0.parquet\", \"means_path\": \"data/sim/power/means/055fea2d4bc0.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"sub\", \"label\": \"main\", \"g\": 3.2, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"5e3aa50ce079\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/5e3aa50ce079.parquet\", \"means_path\": \"data/sim/power/means/5e3aa50ce079.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"sub\", \"label\": \"main\", \"g\": 0.15, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"8ddc8a669c4f\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/8ddc8a669c4f.parquet\", \"means_path\": \"data/sim/power/means/8ddc8a669c4f.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"sub\", \"label\": \"main\", \"g\": 0.4, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"0d42b586b7d5\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/0d42b586b7d5.parquet\", \"means_path\": \"data/sim/power/means/0d42b586b7d5.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"sub\", \"label\": \"main\", \"g\": 0.8, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"3fec1c83615e\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/3fec1c83615e.parquet\", \"means_path\": \"data/sim/power/means/3fec1c83615e.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"sub\", \"label\": \"main\", \"g\": 1.6, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"dc827e3e8f81\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/dc827e3e8f81.parquet\", \"means_path\": \"data/sim/power/means/dc827e3e8f81.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [0.4472135954999579, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"sub\", \"label\": \"main\", \"g\": 3.2, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"3f417b0bc049\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/3f417b0bc049.parquet\", \"means_path\": \"data/sim/power/means/3f417b0bc049.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.15, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"6462948bd644\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/6462948bd644.parquet\", \"means_path\": \"data/sim/power/means/6462948bd644.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.4, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"373dfb444a5a\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/373dfb444a5a.parquet\", \"means_path\": \"data/sim/power/means/373dfb444a5a.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.8, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"0c201b0c0b9b\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/0c201b0c0b9b.parquet\", \"means_path\": \"data/sim/power/means/0c201b0c0b9b.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 1.6, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"934fca21dfa4\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/934fca21dfa4.parquet\", \"means_path\": \"data/sim/power/means/934fca21dfa4.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 0.5235987755982988, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 3.2, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"dad1dfcd18e9\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/dad1dfcd18e9.parquet\", \"means_path\": \"data/sim/power/means/dad1dfcd18e9.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.15, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"4df937b2be51\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/4df937b2be51.parquet\", \"means_path\": \"data/sim/power/means/4df937b2be51.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.4, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"9f2a6ba347a8\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/9f2a6ba347a8.parquet\", \"means_path\": \"data/sim/power/means/9f2a6ba347a8.npz\", \"_rank\": 4, \"_sweep\": \"power\"}, {\"config\": {\"n\": 2000, \"p\": 1600, \"r\": 3, \"l\": [2.6832815729997477, 0.4472135954999579, 0.4472135954999579], \"theta\": 1.5707963267948966, \"profile\": \"mixed\", \"label\": \"main\", \"g\": 0.8, \"q_fixed\": true, \"twin_gamma0\": false}, \"config_id\": \"d115d8501cc9\", \"mode\": \"power\", \"sweep\": \"power\", \"reps\": 300, \"raw_path\": \"data/sim/power/raw/d115d8501cc9.parquet\", \"means_path\": \"data/sim/power/means/d115d8501cc9.npz\", \"_rank\": 4, \"_sweep\": \"power\"}]")

def _safe(job):
    try:
        return run_cell(job)
    except Exception as e:
        print('[FAIL]', job['config_id'], repr(e))
        traceback.print_exc()
        return job['config_id'], -1.0

t0 = time.time()
results = []
for i, job in enumerate(JOBS):
    if time.time() - t0 > 8.6 * 3600:
        print('[WALL LIMIT] stopping cleanly after', i, 'jobs')
        break
    results.append(_safe(job))
print('shard done:', results)

# %%
import hashlib, json, glob, os
manifest = {'shard_id': 30, 'files': {}}
os.makedirs('data', exist_ok=True)
for f in sorted(glob.glob('data/**/*.parquet', recursive=True)) + \
         sorted(glob.glob('data/**/*.npz', recursive=True)):
    h = hashlib.sha256(open(f, 'rb').read()).hexdigest()
    manifest['files'][f] = h
with open('data/manifest.json', 'w') as fh:
    json.dump(manifest, fh, indent=1)
print(json.dumps(manifest['files'], indent=1))

# %%
import shutil
archive = shutil.make_archive('scf_shard_{:02d}'.format(30), 'zip', 'data')
print('archived:', archive)
output_file = archive
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
